# %%
import pandas as pd

# %%
df_local = pd.read_csv('olist_geolocation_dataset.csv')
df_local
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
df_local.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
df_local.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
df_local.describe(include='all')
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# count                  1.000163e+06     1.000163e+06     1.000163e+06
# unique                          NaN              NaN              NaN
# top                             NaN              NaN              NaN
# freq                            NaN              NaN              NaN
# mean                   3.657417e+04    -2.117615e+01    -4.639054e+01
# std                    3.054934e+04     5.715866e+00     4.269748e+00
# min                    1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                    1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                    2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                    6.350400e+04    -1.997962e+01    -4.376771e+01
# max                    9.999000e+04     4.506593e+01     1.211054e+02
#
#        geolocation_city geolocation_state
# count           1000163           1000163
# ...

# %%
df_local['geolocation_state'].value_counts()
# Out:
# geolocation_state
# SP    404268
# MG    126336
# RJ    121169
# RS     61851
# PR     57859
# SC     38328
# BA     36045
# GO     20139
# ES     16748
# PE     16432
# DF     12986
# MT     12031
# CE     11674
# PA     10853
# MS     10431
# MA      7853
# PB      5538
# RN      5041
# PI      4549
# AL      4183
# TO      3576
# SE      3563
# RO      3478
# AM      2432
# AC      1301
# AP       853
# RR       646
# Name: count, dtype: int64

# %%
df_local['geolocation_state'].value_counts(normalize=True)*100
# Out:
# geolocation_state
# SP    40.420212
# MG    12.631541
# RJ    12.114925
# RS     6.184092
# PR     5.784957
# SC     3.832175
# BA     3.603913
# GO     2.013572
# ES     1.674527
# PE     1.642932
# DF     1.298388
# MT     1.202904
# CE     1.167210
# PA     1.085123
# MS     1.042930
# MA     0.785172
# PB     0.553710
# RN     0.504018
# PI     0.454826
# AL     0.418232
# TO     0.357542
# SE     0.356242
# RO     0.347743
# AM     0.243160
# AC     0.130079
# AP     0.085286
# RR     0.064589
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(data=df_local[['geolocation_state']], x ='geolocation_state')

plt.show()

# %%
df_product = pd.read_csv('olist_products_dataset.csv')

# %%
df_product.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
df_product['product_category_name'].value_counts()
# Out:
# product_category_name
# cama_mesa_banho                  2889
# esporte_lazer                    2759
# moveis_decoracao                 2460
# beleza_saude                     2385
# utilidades_domesticas            2150
#                                  ...
# fashion_roupa_infanto_juvenil       5
# moveis_colchao_e_estofado           5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: count, Length: 74, dtype: int64

# %%
df_product['product_category_name'].value_counts(normalize=True)*100
# Out:
# product_category_name
# cama_mesa_banho                  8.922450
# esporte_lazer                    8.520955
# moveis_decoracao                 7.597517
# beleza_saude                     7.365885
# utilidades_domesticas            6.640106
#                                    ...
# fashion_roupa_infanto_juvenil    0.015442
# moveis_colchao_e_estofado        0.015442
# pc_gamer                         0.009265
# seguros_e_servicos               0.006177
# cds_dvds_musicais                0.003088
# Name: proportion, Length: 74, dtype: float64

# %%
sns.countplot(data=df_product[['product_category_name']].sort_values ('product_category_name'), x= 'product_category_name')

plt.show()

# %%
counts = df_product['product_category_name'].value_counts().reset_index()
counts.columns = ['product_category_name', 'count']
counts = counts.sort_values(by='count', ascending=True)

plt.figure(figsize=(20, 10))
ax = sns.barplot(y='product_category_name', x='count', data=counts, palette='viridis')
plt.xlabel('Contagem')
plt.ylabel('Categoria de Produto')
plt.title('Contagem de Cada Categoria de Produto')
plt.show()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_87924\3513576434.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(y='product_category_name', x='count', data=counts, palette='viridis')

# %%
df_product.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
df_product.describe(include ='all')
# Out:
#                               product_id product_category_name  \
# count                              32951                 32341
# unique                             32951                    73
# top     106392145fca363410d287a815be6de4       cama_mesa_banho
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32341.000000                32341.000000        32341.000000
# ...

# %%
df_product.dtypes
# Out:
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object

# %%
df_product.loc[df_product['product_weight_g'] < 1000, 'peso'] = '< 1kg'
df_product.loc[(df_product['product_weight_g'] >= 1000) & (df_product['product_weight_g'] <= 5000), 'peso'] = ' 1kg - 5 kg'
df_product.loc[(df_product['product_weight_g'] > 5000) & (df_product['product_weight_g'] <= 10000), 'peso'] = '5kg - 10 kg'
df_product.loc[df_product['product_weight_g'] > 10000] = '> 10 kg'
df_product
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_87924\2151453695.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '> 10 kg' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_product.loc[df_product['product_weight_g'] > 10000] = '> 10 kg'
# C:\Users\andre\AppData\Local\Temp\ipykernel_87924\2151453695.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '> 10 kg' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_product.loc[df_product['product_weight_g'] > 10000] = '> 10 kg'
# ...

# %% [markdown]
# Professora tem algo dando errado aqui, porque os dados estão virando object, mas eu não sei o que é
# HEEEEEEEEEEEEELP

# %%
df_product.dtypes
# Out:
# product_id                    object
# product_category_name         object
# product_name_lenght           object
# product_description_lenght    object
# product_photos_qty            object
# product_weight_g              object
# product_length_cm             object
# product_height_cm             object
# product_width_cm              object
# peso                          object
# dtype: object

# %%
df_product['product_weight_g'].value_counts()
# Out:
# product_weight_g
# 200.0      2084
# > 10 kg    1891
# 300.0      1561
# 150.0      1259
# 400.0      1206
#            ...
# 1470.0        1
# 2738.0        1
# 964.0         1
# 989.0         1
# 1154.0        1
# Name: count, Length: 1735, dtype: int64

# %%
df_orders = pd.read_csv(r'olist_orders_dataset.csv')
df_orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_products = pd.read_csv(r'olist_order_items_dataset.csv')
df_products
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_comum = pd.merge(df_products, df_product, left_on='product_id', right_on='product_id', how='outer')
df_comum
# Out:
#                                 order_id  order_item_id  \
# 0       f30149f4a8882a08895b6a242aa0d612            1.0
# 1       f5eda0ded77c1293b04c953138c8331d            1.0
# 2       0bf736fd0fd5169d60de3699fcbcf986            1.0
# 3       3aba44d8e554ab4bb8c09f6f78032ca8            1.0
# 4       6f0dfb5b5398b271cc6bbd9ee263530e            1.0
# ...                                  ...            ...
# 114536  a8159270bc9cf7d54450e079ba6b7232            1.0
# 114537  beaf95465b542dea76df78b2fb86a97a            1.0
# 114538  d6c1ed12e8eeaa15e9d5c83c79598f85            1.0
# 114539  dd38c566a34ff9deb93ff05d7bd6d0aa            1.0
# 114540  fbf3da6fe82010412982890b0c57e532            1.0
#
#                               product_id                         seller_id  \
# 0       00066f42aeeb9f3007548bb9d3f33c38  5670f4db5b62c43d542e1b2d56b0cf7c
# 1       00088930e925c41fd95ebfe695fd2655  7142540dd4c91e2237acb7e911c4eba2
# ...

# %%
df_comum.head()
# Out:
#                            order_id  order_item_id  \
# 0  f30149f4a8882a08895b6a242aa0d612            1.0
# 1  f5eda0ded77c1293b04c953138c8331d            1.0
# 2  0bf736fd0fd5169d60de3699fcbcf986            1.0
# 3  3aba44d8e554ab4bb8c09f6f78032ca8            1.0
# 4  6f0dfb5b5398b271cc6bbd9ee263530e            1.0
#
#                          product_id                         seller_id  \
# 0  00066f42aeeb9f3007548bb9d3f33c38  5670f4db5b62c43d542e1b2d56b0cf7c
# 1  00088930e925c41fd95ebfe695fd2655  7142540dd4c91e2237acb7e911c4eba2
# 2  0009406fd7479715e4bef61dd91f2462  4a3ca9315b744ce9f8e9374361493884
# 3  000b8f95fcb9e0096488278317764d19  40ec8ab6cdafbcc4f544da38c67da39a
# 4  000b8f95fcb9e0096488278317764d19  40ec8ab6cdafbcc4f544da38c67da39a
#
#    shipping_limit_date   price  freight_value  product_category_name  \
# 0  2018-05-24 18:58:59  101.65          18.59             perfumaria
# 1  2017-12-18 19:32:19  129.90          13.93             automotivo
# ...

# %%
df_comum.dtypes
# Out:
# order_id                       object
# order_item_id                 float64
# product_id                     object
# seller_id                      object
# shipping_limit_date            object
# price                         float64
# freight_value                 float64
# product_category_name          object
# product_name_lenght            object
# product_description_lenght     object
# product_photos_qty             object
# product_weight_g               object
# product_length_cm              object
# product_height_cm              object
# product_width_cm               object
# peso                           object
# dtype: object

# %%
df_comum['freight_value'].value_counts()
# Out:
# freight_value
# 15.10    3707
# 7.78     2262
# 14.10    1875
# 11.85    1846
# 18.23    1575
#          ...
# 6.30        1
# 65.59       1
# 55.91       1
# 98.37       1
# 94.78       1
# Name: count, Length: 6999, dtype: int64

# %%
df_comum['price'].value_counts()
# Out:
# price
# 59.90     2481
# 69.90     1987
# 49.90     1953
# 89.90     1548
# 99.90     1432
#           ...
# 416.00       1
# 319.29       1
# 8.20         1
# 10.89        1
# 73.97        1
# Name: count, Length: 5968, dtype: int64

# %%
df_comum['price'].describe()
# Out:
# count    112650.000000
# mean        120.653739
# std         183.633928
# min           0.850000
# 25%          39.900000
# 50%          74.990000
# 75%         134.900000
# max        6735.000000
# Name: price, dtype: float64

# %% [markdown]
# Grupos de preço

# %%
df_comum.loc[df_comum['price'] <= 100, 'grupo_preco'] = '0 - 100'
df_comum.loc[(df_comum['price'] > 100) & (df_comum['price'] <= 500), 'grupo_preco'] = '101 - 500'
df_comum.loc[(df_comum['price'] > 500) & (df_comum['price'] <= 1000), 'grupo_preco'] = '501 - 1000'
df_comum.loc[(df_comum['price'] > 1000), 'grupo_preco'] = 'Maior 1000'

df_comum
# Out:
#                                 order_id  order_item_id  \
# 0       f30149f4a8882a08895b6a242aa0d612            1.0
# 1       f5eda0ded77c1293b04c953138c8331d            1.0
# 2       0bf736fd0fd5169d60de3699fcbcf986            1.0
# 3       3aba44d8e554ab4bb8c09f6f78032ca8            1.0
# 4       6f0dfb5b5398b271cc6bbd9ee263530e            1.0
# ...                                  ...            ...
# 114536  a8159270bc9cf7d54450e079ba6b7232            1.0
# 114537  beaf95465b542dea76df78b2fb86a97a            1.0
# 114538  d6c1ed12e8eeaa15e9d5c83c79598f85            1.0
# 114539  dd38c566a34ff9deb93ff05d7bd6d0aa            1.0
# 114540  fbf3da6fe82010412982890b0c57e532            1.0
#
#                               product_id                         seller_id  \
# 0       00066f42aeeb9f3007548bb9d3f33c38  5670f4db5b62c43d542e1b2d56b0cf7c
# 1       00088930e925c41fd95ebfe695fd2655  7142540dd4c91e2237acb7e911c4eba2
# ...

# %%
sns.countplot(data=df_comum[['grupo_preco']], x = 'grupo_preco')

plt.show()
